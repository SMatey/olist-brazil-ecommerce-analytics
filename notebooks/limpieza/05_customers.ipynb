# %% [markdown]
# ## Limpieza de datos, archivo:

# %%
# =========================
# Importaciones
# =========================
import pandas as pd

# Ruta base (ajústala si corresponde)
RAW = "../../data/raw/"

# =========================
# Carga de datos
# =========================
customers = pd.read_csv(RAW + "olist_customers_dataset.csv")

print(f"Filas iniciales: {len(customers):,}")

# =========================
# Limpieza mínima según EDA
# =========================

# Duplicados 
customers = customers.drop_duplicates(subset=["customer_id"], keep="first").copy()

# =========================
# Resultado final
# =========================
customers_clean = customers.copy()
print(f"Filas finales: {len(customers_clean):,}")
print(customers_clean.dtypes)

# Vista rápida
customers_clean.head()
# Out:
# Filas iniciales: 99,441
# Filas finales: 99,441
# customer_id                 object
# customer_unique_id          object
# customer_zip_code_prefix     int64
# customer_city               object
# customer_state              object
# dtype: object
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state
# 0                     14409                 franca             SP
# 1                      9790  sao bernardo do campo             SP
# 2                      1151              sao paulo             SP
# ...

# %% [markdown]
# ## Resultados de limpieza

# %% [markdown]
# ## Guardar DataFrame limpio
